# %%
import geopandas as gpd
import folium

# Load your exported Overpass Turbo data
gdf = gpd.read_file("export.geojson")

# Optional: inspect what columns you have
gdf.head()
# Out:
#                  id               @id abandoned:historic access addr:city  \
# 0  relation/2312684  relation/2312684               None   None      None
# 1  relation/3412518  relation/3412518               None   None      None
# 2      way/31962395      way/31962395               None   None  Toshkent
# 3      way/31972619      way/31972619               None   None  Toshkent
# 4      way/31974956      way/31974956               None   None  Toshkent
#
#   addr:city:en addr:country addr:floor addr:housenumber addr:place  ...  \
# 0         None         None       None             None       None  ...
# 1         None         None       None              101       None  ...
# 2     Tashkent         None       None               28       None  ...
# 3     Tashkent         None       None                1       None  ...
# 4         None         None       None                3       None  ...
#
#   tourism          type                         website wheelchair   wikidata  \
# 0    None  multipolygon                            None       None  Q59590271
# 1  museum  multipolygon                            None       None       None
# 2    None          None                https://gabt.uz/       None   Q3354568
# 3  museum          None                            None       None   Q4120971
# 4  museum          None  https://www.history-museum.uz/       None   Q1835285
#
#                                  wikimedia_commons  \
# 0                                             None
# 1                                             None
# 2  Category:Alisher Navoi Opera and Ballet Theatre
# 3                       Category:Amir Timur Museum
# 4   Category:State Museum of History of Uzbekistan
#
#                                   wikipedia wikipedia:ru @geometry  \
# 0                                      None         None    center
# 1                                      None         None    center
# 2      ru:Большой театр имени Алишера Навои         None    center
# 3        uz:Temuriylar tarixi davlat muzeyi         None    center
# 4  en:State Museum of History of Uzbekistan         None    center
#
#                     geometry
# 0  POINT (69.24304 41.32475)
# 1  POINT (69.28048 41.30536)
# 2  POINT (69.27152 41.30922)
# 3  POINT (69.27899 41.31368)
# 4  POINT (69.26933 41.31162)
#
# [5 rows x 96 columns]

# %%
art_gdf = gdf[
    gdf.apply(
        lambda row: any(
            str(row.get(c, "")).lower() in [
                "museum", "artwork", "gallery", "monument", "memorial"
            ]
            for c in ["tourism", "amenity", "artwork_type"]
        ),
        axis=1
    )
]

# %%
# Center map roughly around Tashkent
m = folium.Map(location=[41.3111, 69.2797], zoom_start=12, tiles="cartodb positron")

# Add points
for _, row in art_gdf.iterrows():
    lat, lon = row.geometry.y, row.geometry.x
    name = row.get("name", "Unnamed site")
    cat = row.get("tourism") or row.get("amenity") or row.get("artwork_type")
    desc = "<br>".join([f"<b>{k}</b>: {v}" for k, v in row.items() if isinstance(v, str) and v])

    folium.CircleMarker(
        location=[lat, lon],
        radius=6,
        color="crimson",
        fill=True,
        fill_opacity=0.8,
        popup=folium.Popup(f"<b>{name}</b><br>{cat}<br><small>{desc}</small>", max_width=250),
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85da334d822c1cb92dede569054fd9c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85da334d822c1cb92dede569054fd9c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85da334d822c1cb92dede569054fd9c2 = L.map(
#                 &quot;map_85da334d822c1cb92dede569054fd9c2&quot;,
#                 {
#                     center: [41.3111, 69.2797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36b414c213d764c1b5f9877ed4d0fe4d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36b414c213d764c1b5f9877ed4d0fe4d.addTo(map_85da334d822c1cb92dede569054fd9c2);
#
#
#             var circle_marker_2cdfc8e1194bc418d46023d4eb6e5d15 = L.circleMarker(
#                 [41.3053601, 69.2804814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_85da334d822c1cb92dede569054fd9c2);
#
#
#         var popup_c804141e11a9cf89041ccd5f51c23d64 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_3909792d2279eecbbcedd225f8e024cd = $(`&lt;div id=&quot;html_3909792d2279eecbbcedd225f8e024cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Центр современного искусства&lt;/b&gt;&lt;br&gt;museum&lt;br&gt;&lt;small&gt;&lt;b&gt;id&lt;/b&gt;: relation/3412518&lt;br&gt;&lt;b&gt;@id&lt;/b&gt;: relation/3412518&lt;br&gt;&lt;b&gt;addr:housenumber&lt;/b&gt;: 101&lt;br&gt;&lt;b&gt;building&lt;/b&gt;: yes&lt;br&gt;&lt;b&gt;building:levels&lt;/b&gt;: 2&lt;br&gt;&lt;b&gt;building:material&lt;/b&gt;: brick&lt;br&gt;&lt;b&gt;building:name&lt;/b&gt;: Дизельная&lt;br&gt;&lt;b&gt;height&lt;/b&gt;: 15&lt;br&gt;&lt;b&gt;name&lt;/b&gt;: Центр современного искусства&lt;br&gt;&lt;b&gt;old_name&lt;/b&gt;: Дизельная&lt;br&gt;&lt;b&gt;roof:angle&lt;/b&gt;: 21&lt;br&gt;&lt;b&gt;roof:colour&lt;/b&gt;: red&lt;br&gt;&lt;b&gt;roof:shape&lt;/b&gt;: gabled&lt;br&gt;&lt;b&gt;tourism&lt;/b&gt;: museum&lt;br&gt;&lt;b&gt;type&lt;/b&gt;: multipolygon&lt;br&gt;&lt;b&gt;@geometry&lt;/b&gt;: center&lt;/small&gt;&lt;/div&gt;`)[0];
#                 popup_c804141e11a9cf89041ccd5f51c23d64.setContent(html_3909792d2279eecbbcedd225f8e024cd);
#
#
#
#         circle_marker_2cdfc8e1194bc418d46023d4eb6e5d15.bindPopup(popup_c804141e11a9cf89041ccd5f51c23d64)
#         ;
#
#
#
#
#             var circle_marker_caa444c06a39dc440765383978b612ef = L.circleMarker(
#                 [41.3136825, 69.2789874],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_85da334d822c1cb92dede569054fd9c2);
#
#
#         var popup_d56eeea4fe2fd54537fe1e2c2aef49d3 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_9b9e126959391fb73341c6a48734d6fe = $(`&lt;div id=&quot;html_9b9e126959391fb73341c6a48734d6fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Temuriylar tarixi davlat muzeyi&lt;/b&gt;&lt;br&gt;museum&lt;br&gt;&lt;small&gt;&lt;b&gt;id&lt;/b&gt;: way/31972619&lt;br&gt;&lt;b&gt;@id&lt;/b&gt;: way/31972619&lt;br&gt;&lt;b&gt;addr:city&lt;/b&gt;: Toshkent&lt;br&gt;&lt;b&gt;addr:city:en&lt;/b&gt;: Tashkent&lt;br&gt;&lt;b&gt;addr:housenumber&lt;/b&gt;: 1&lt;br&gt;&lt;b&gt;addr:postcode&lt;/b&gt;: 100000&lt;br&gt;&lt;b&gt;addr:street&lt;/b&gt;: Amir Temur shoh ko&#x27;chasi&lt;br&gt;&lt;b&gt;alt_name&lt;/b&gt;: Музей Амира Темура&lt;br&gt;&lt;b&gt;building&lt;/b&gt;: museum&lt;br&gt;&lt;b&gt;museum&lt;/b&gt;: history&lt;br&gt;&lt;b&gt;name&lt;/b&gt;: Temuriylar tarixi davlat muzeyi&lt;br&gt;&lt;b&gt;name:en&lt;/b&gt;: State Museu

# %%
import random

# Assign random colors by main category
cats = art_gdf['tourism'].fillna(art_gdf['amenity']).fillna(art_gdf['artwork_type'])
unique_cats = cats.unique()
colors = {cat: f"#{random.randint(0, 0xFFFFFF):06x}" for cat in unique_cats}

m = folium.Map(location=[41.3111, 69.2797], zoom_start=12, tiles="cartodb dark_matter")

for _, row in art_gdf.iterrows():
    cat = row.get("tourism") or row.get("amenity") or row.get("artwork_type") or "other"
    color = colors.get(cat, "#ffcc00")
    folium.CircleMarker(
        location=[row.geometry.y, row.geometry.x],
        radius=6,
        color=color,
        fill=True,
        fill_opacity=0.8,
        popup=row.get("name", "Unnamed site"),
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a5e6d165283557b09fae25c4de65220 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a5e6d165283557b09fae25c4de65220&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a5e6d165283557b09fae25c4de65220 = L.map(
#                 &quot;map_1a5e6d165283557b09fae25c4de65220&quot;,
#                 {
#                     center: [41.3111, 69.2797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a91bd1bdaed0a7ca67fe9ee8dc102acf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a91bd1bdaed0a7ca67fe9ee8dc102acf.addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#             var circle_marker_7acaa448b23a2afcc7a78473a6928891 = L.circleMarker(
#                 [41.3053601, 69.2804814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e333ca&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e333ca&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#         var popup_7a4d9b68fb55c148df6e2e0547738664 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6631e4de8ac5ce5c70963a0a62e452e4 = $(`&lt;div id=&quot;html_6631e4de8ac5ce5c70963a0a62e452e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Центр современного искусства&lt;/div&gt;`)[0];
#                 popup_7a4d9b68fb55c148df6e2e0547738664.setContent(html_6631e4de8ac5ce5c70963a0a62e452e4);
#
#
#
#         circle_marker_7acaa448b23a2afcc7a78473a6928891.bindPopup(popup_7a4d9b68fb55c148df6e2e0547738664)
#         ;
#
#
#
#
#             var circle_marker_0abdf15ebe49840cdaa217d37b71f093 = L.circleMarker(
#                 [41.3136825, 69.2789874],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e333ca&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e333ca&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#         var popup_ba8e13178bcff818e9d9220258499a05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9becdb9d8a2fde749270736b5ff5c094 = $(`&lt;div id=&quot;html_9becdb9d8a2fde749270736b5ff5c094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temuriylar tarixi davlat muzeyi&lt;/div&gt;`)[0];
#                 popup_ba8e13178bcff818e9d9220258499a05.setContent(html_9becdb9d8a2fde749270736b5ff5c094);
#
#
#
#         circle_marker_0abdf15ebe49840cdaa217d37b71f093.bindPopup(popup_ba8e13178bcff818e9d9220258499a05)
#         ;
#
#
#
#
#             var circle_marker_567e8e3ee88104662dfa18d66691bbd6 = L.circleMarker(
#                 [41.311623, 69.269333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e333ca&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e333ca&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#         var popup_eb761d5470a20dce1102aa2ba3f0730e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69d0f5dcd729239e26da72d3ac30a0a2 = $(`&lt;div id=&quot;html_69d0f5dcd729239e26da72d3ac30a0a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;O&#x27;zbekiston Tarixi Davlat Muzeyi&lt;/div&gt;`)[0];
#                 popup_eb761d5470a20dce1102aa2ba3f0730e.setContent(html_69d0f5dcd729239e26da72d3ac30a0a2);
#
#
#
#         circle_marker_567e

# %%
category_styles = {
    "museum": {"icon": "university", "color": "darkblue"},
    "gallery": {"icon": "palette", "color": "purple"},
    "artwork": {"icon": "paint-brush", "color": "orange"},
    "monument": {"icon": "landmark", "color": "darkred"},
    "memorial": {"icon": "cross", "color": "gray"},
}

# %%
for _, row in art_gdf.iterrows():
    lat, lon = row.geometry.y, row.geometry.x
    cat = (row.get("tourism") or row.get("amenity") or row.get("artwork_type") or "other").lower()
    name = row.get("name", "Unnamed site")
    desc = "<br>".join(
        [f"<b>{k}</b>: {v}" for k, v in row.items() if isinstance(v, str) and v]
    )

    style = category_styles.get(cat, {"icon": "circle", "color": "lightgray"})

    folium.Marker(
        location=[lat, lon],
        icon=folium.Icon(color=style["color"], icon=style["icon"], prefix="fa"),
        popup=folium.Popup(f"<b>{name}</b><br>{cat}<br><small>{desc}</small>", max_width=300),
    ).add_to(m)

# %%
legend_html = """
<div style="
position: fixed; 
bottom: 40px; left: 40px; width: 180px; 
background-color: rgba(255,255,255,0.8); 
padding: 10px; 
border-radius: 10px;
box-shadow: 0 0 10px rgba(0,0,0,0.3);
z-index:9999;
font-size:14px;">
<b>Legend</b><br>
<i class="fa fa-university" style="color:darkblue"></i> Museum<br>
<i class="fa fa-palette" style="color:purple"></i> Gallery<br>
<i class="fa fa-paint-brush" style="color:orange"></i> Artwork<br>
<i class="fa fa-landmark" style="color:darkred"></i> Monument<br>
<i class="fa fa-cross" style="color:gray"></i> Memorial<br>
</div>
"""
m.get_root().html.add_child(folium.Element(legend_html))

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a5e6d165283557b09fae25c4de65220 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a5e6d165283557b09fae25c4de65220&quot; &gt;&lt;/div&gt;
#
#
# &lt;div style=&quot;
# position: fixed;
# bottom: 40px; left: 40px; width: 180px;
# background-color: rgba(255,255,255,0.8);
# padding: 10px;
# border-radius: 10px;
# box-shadow: 0 0 10px rgba(0,0,0,0.3);
# z-index:9999;
# font-size:14px;&quot;&gt;
# &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
# &lt;i class=&quot;fa fa-university&quot; style=&quot;color:darkblue&quot;&gt;&lt;/i&gt; Museum&lt;br&gt;
# &lt;i class=&quot;fa fa-palette&quot; style=&quot;color:purple&quot;&gt;&lt;/i&gt; Gallery&lt;br&gt;
# &lt;i class=&quot;fa fa-paint-brush&quot; style=&quot;color:orange&quot;&gt;&lt;/i&gt; Artwork&lt;br&gt;
# &lt;i class=&quot;fa fa-landmark&quot; style=&quot;color:darkred&quot;&gt;&lt;/i&gt; Monument&lt;br&gt;
# &lt;i class=&quot;fa fa-cross&quot; style=&quot;color:gray&quot;&gt;&lt;/i&gt; Memorial&lt;br&gt;
# &lt;/div&gt;
#
# &lt;div style=&quot;
# position: fixed;
# bottom: 40px; left: 40px; width: 180px;
# background-color: rgba(255,255,255,0.8);
# padding: 10px;
# border-radius: 10px;
# box-shadow: 0 0 10px rgba(0,0,0,0.3);
# z-index:9999;
# font-size:14px;&quot;&gt;
# &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
# &lt;i class=&quot;fa fa-university&quot; style=&quot;color:darkblue&quot;&gt;&lt;/i&gt; Museum&lt;br&gt;
# &lt;i class=&quot;fa fa-palette&quot; style=&quot;color:purple&quot;&gt;&lt;/i&gt; Gallery&lt;br&gt;
# &lt;i class=&quot;fa fa-paint-brush&quot; style=&quot;color:orange&quot;&gt;&lt;/i&gt; Artwork&lt;br&gt;
# &lt;i class=&quot;fa fa-landmark&quot; style=&quot;color:darkred&quot;&gt;&lt;/i&gt; Monument&lt;br&gt;
# &lt;i class=&quot;fa fa-cross&quot; style=&quot;color:gray&quot;&gt;&lt;/i&gt; Memorial&lt;br&gt;
# &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a5e6d165283557b09fae25c4de65220 = L.map(
#                 &quot;map_1a5e6d165283557b09fae25c4de65220&quot;,
#                 {
#                     center: [41.3111, 69.2797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a91bd1bdaed0a7ca67fe9ee8dc102acf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a91bd1bdaed0a7ca67fe9ee8dc102acf.addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#             var circle_marker_7acaa448b23a2afcc7a78473a6928891 = L.circleMarker(
#                 [41.3053601, 69.2804814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e333ca&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e333ca&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#         var popup_7a4d9b68fb55c148df6e2e0547738664 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6631e4de8ac5ce5c70963a0a62e452e4 = $(`&lt;div id=&quot;html_6631e4de8ac5ce5c70963a0a62e452e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Центр современного искусства&lt;/div&gt;`)[0];
#                 popup_7a4d9b68fb55c148df6e2e0547738664.setContent(html_6631e4de8ac5ce5c70963a0a62e452e4);
#
#
#
#         circle_marker_7acaa448b23a2afcc7a78473a6928891.bindPopup(popup_7a4d9b68fb55c148df6e2e0547738664)
#         ;
#
#
#
#
#             var circle_marker_0abdf15ebe49840cdaa217d37b71f093 = L.circleMarker(
#                 [41.3136825, 69.2789874],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e333ca&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e333ca&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#         var popup_ba8e13178bcff818e9d9220258499a05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9becdb9d8a2fde749270736b5ff5c094 = $(`&lt;div

# %%
m.save("Day 1 - art points")

# %%
import geopandas as gpd

# Load the shapefile (admin boundaries)
boundaries = gpd.read_file("uzb_admbnda_adm1_2018b.shp")

# %%
boundaries
# Out:
#        ADM0_EN                ADM0_RU                   ADM0_UZ  \
# 0   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 1   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 2   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 3   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 4   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 5   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 6   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 7   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 8   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 9   Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 10  Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 11  Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 12  Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
# 13  Uzbekistan  Республика Узбекистан  O'zbekiston Respublikasi
#
#                 ADM0ALT1EN ADM0_PCODE                     ADM1_EN  \
# 0   Republic of Uzbekistan         UZ                    Andizhan
# 1   Republic of Uzbekistan         UZ                     Bukhara
# 2   Republic of Uzbekistan         UZ                     Dzhizak
# 3   Republic of Uzbekistan         UZ                     Fergana
# 4   Republic of Uzbekistan         UZ                 Kashkadarya
# 5   Republic of Uzbekistan         UZ                     Khorezm
# 6   Republic of Uzbekistan         UZ                    Namangan
# 7   Republic of Uzbekistan         UZ                       Navoi
# 8   Republic of Uzbekistan         UZ  Republic of Karakalpakstan
# 9   Republic of Uzbekistan         UZ                   Samarkand
# 10  Republic of Uzbekistan         UZ                Surkhandarya
# 11  Republic of Uzbekistan         UZ                    Syrdarya
# 12  Republic of Uzbekistan         UZ                    Tashkent
# 13  Republic of Uzbekistan         UZ               Tashkent city
#
#                       ADM1_RU                        ADM1_UZ  \
# 0                 Андижанская                        Andijon
# 1                   Бухарская                         Buxoro
# 2                  Джизакская                         Jizzax
# 3                  Ферганская                       Farg'ona
# 4             Кашкадарьинская                    Qashqadaryo
# 5                  Хорезмская                         Xorazm
# 6                Наманганская                       Namangan
# 7                  Навоийская                         Navoiy
# 8   Республика Каракалпакстан  Qoraqalpog'iston Respublikasi
# 9               Самаркандская                      Samarqand
# 10           Сурхандарьинская                    Surxandaryo
# 11              Сырдарьинская                       Sirdaryo
# 12                Ташкентская                       Toshkent
# 13                  г.Ташкент                    Toshkent ш.
#
#              ADM1TYPE_E             ADM1TYPE_R           ADM1TYPE_U  \
# 0              province                область             viloyati
# 1              province                область             viloyati
# 2              province                область             viloyati
# 3              province                область             viloyati
# 4              province                область             viloyati
# 5              province                область             viloyati
# 6              province                область             viloyati
# 7              province                область             viloyati
# 8   autonomous republic  автономная республика  muxtor respublikasi
# 9              province                область             viloyati
# 10             province                область             viloyati
# 11             province                область             viloyati
# 12             province                область             viloyati
# 13     independent city                  город               shahri
#
#    ADM1_PCODE                                           geometry
# 0        UZ03  POLYGON ((72.35866 41.06426, 72.36182 41.06137...
# 1        UZ06  POLYGON ((63.6738 40.67516, 63.68308 40.65618,...
# 2        UZ08  POLYGON ((67.32946 41.20266, 67.34834 41.20059...
# 3        UZ30  MULTIPOLYGON (((71.83504 39.98598, 71.8387 39....
# 4        UZ10  POLYGON ((65.75394 39.51051, 65.76572 39.49956...
# 5        UZ33  POLYGON ((60.25193 41.95384, 60.27243 41.9343,...
# 6        UZ14  POLYGON ((71.70757 41.42406, 71.71663 41.41976...
# 7        UZ12  POLYGON ((65.25539 43.60787, 65.26723 43.5886,...
# 8        UZ35  POLYGON ((61.04586 44.39032, 61.04997 44.3863,...
# 9        UZ18  POLYGON ((66.43228 40.59085, 66.45001 40.58405...
# 10       UZ22  POLYGON ((67.97571 39.03334, 67.98772 39.02164...
# 11       UZ24  POLYGON ((68.6981 40.83378, 68.70239 40.83279,...
# 12       UZ27  MULTIPOLYGON (((69.28937 41.2057, 69.29112 41....
# 13       UZ26  POLYGON ((69.25358 41.35113, 69.25994 41.35055...

# %%
import folium

# --- add boundary layer ---
folium.GeoJson(
    tashkent_boundary if 'tashkent_boundary' in locals() else boundaries,
    name="Administrative Boundary",
    style_function=lambda x: {
        'fillColor': 'none',
        'color': 'white',
        'weight': 2,
        'opacity': 0.8
    }
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a5e6d165283557b09fae25c4de65220 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a5e6d165283557b09fae25c4de65220&quot; &gt;&lt;/div&gt;
#
#
# &lt;div style=&quot;
# position: fixed;
# bottom: 40px; left: 40px; width: 180px;
# background-color: rgba(255,255,255,0.8);
# padding: 10px;
# border-radius: 10px;
# box-shadow: 0 0 10px rgba(0,0,0,0.3);
# z-index:9999;
# font-size:14px;&quot;&gt;
# &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
# &lt;i class=&quot;fa fa-university&quot; style=&quot;color:darkblue&quot;&gt;&lt;/i&gt; Museum&lt;br&gt;
# &lt;i class=&quot;fa fa-palette&quot; style=&quot;color:purple&quot;&gt;&lt;/i&gt; Gallery&lt;br&gt;
# &lt;i class=&quot;fa fa-paint-brush&quot; style=&quot;color:orange&quot;&gt;&lt;/i&gt; Artwork&lt;br&gt;
# &lt;i class=&quot;fa fa-landmark&quot; style=&quot;color:darkred&quot;&gt;&lt;/i&gt; Monument&lt;br&gt;
# &lt;i class=&quot;fa fa-cross&quot; style=&quot;color:gray&quot;&gt;&lt;/i&gt; Memorial&lt;br&gt;
# &lt;/div&gt;
#
# &lt;div style=&quot;
# position: fixed;
# bottom: 40px; left: 40px; width: 180px;
# background-color: rgba(255,255,255,0.8);
# padding: 10px;
# border-radius: 10px;
# box-shadow: 0 0 10px rgba(0,0,0,0.3);
# z-index:9999;
# font-size:14px;&quot;&gt;
# &lt;b&gt;Legend&lt;/b&gt;&lt;br&gt;
# &lt;i class=&quot;fa fa-university&quot; style=&quot;color:darkblue&quot;&gt;&lt;/i&gt; Museum&lt;br&gt;
# &lt;i class=&quot;fa fa-palette&quot; style=&quot;color:purple&quot;&gt;&lt;/i&gt; Gallery&lt;br&gt;
# &lt;i class=&quot;fa fa-paint-brush&quot; style=&quot;color:orange&quot;&gt;&lt;/i&gt; Artwork&lt;br&gt;
# &lt;i class=&quot;fa fa-landmark&quot; style=&quot;color:darkred&quot;&gt;&lt;/i&gt; Monument&lt;br&gt;
# &lt;i class=&quot;fa fa-cross&quot; style=&quot;color:gray&quot;&gt;&lt;/i&gt; Memorial&lt;br&gt;
# &lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a5e6d165283557b09fae25c4de65220 = L.map(
#                 &quot;map_1a5e6d165283557b09fae25c4de65220&quot;,
#                 {
#                     center: [41.3111, 69.2797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a91bd1bdaed0a7ca67fe9ee8dc102acf = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a91bd1bdaed0a7ca67fe9ee8dc102acf.addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#             var circle_marker_7acaa448b23a2afcc7a78473a6928891 = L.circleMarker(
#                 [41.3053601, 69.2804814],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e333ca&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e333ca&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#         var popup_7a4d9b68fb55c148df6e2e0547738664 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6631e4de8ac5ce5c70963a0a62e452e4 = $(`&lt;div id=&quot;html_6631e4de8ac5ce5c70963a0a62e452e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Центр современного искусства&lt;/div&gt;`)[0];
#                 popup_7a4d9b68fb55c148df6e2e0547738664.setContent(html_6631e4de8ac5ce5c70963a0a62e452e4);
#
#
#
#         circle_marker_7acaa448b23a2afcc7a78473a6928891.bindPopup(popup_7a4d9b68fb55c148df6e2e0547738664)
#         ;
#
#
#
#
#             var circle_marker_0abdf15ebe49840cdaa217d37b71f093 = L.circleMarker(
#                 [41.3136825, 69.2789874],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e333ca&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e333ca&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1a5e6d165283557b09fae25c4de65220);
#
#
#         var popup_ba8e13178bcff818e9d9220258499a05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9becdb9d8a2fde749270736b5ff5c094 = $(`&lt;div
