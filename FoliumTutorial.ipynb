# %% [markdown]
# <a href="https://colab.research.google.com/github/NodiraTillayeva/30DayMapChallengeUzbekistan/blob/main/FoliumTutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2025.10.5)

# %% [markdown]
# # 🗺️ 1. Creating Your First Map

# %%
import folium

# Create a map centered on a specific location
m = folium.Map(location=[41.3111, 69.2797], zoom_start=10)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62ae34e1f6157fb5caf8be2a0e8bc4ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62ae34e1f6157fb5caf8be2a0e8bc4ce = L.map(
#                 &quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot;,
#                 {
#                     center: [41.3111, 69.2797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ✅ This creates an interactive map centered on Tashkent, Uzbekistan.
# You can zoom, pan, and explore it right inside a Jupyter notebook.

# %% [markdown]
# # 📍 2. Adding Markers
#
# Markers help highlight points of interest on your map.

# %%
folium.Marker(
    location=[41.3275, 69.2817],
    popup="Chorsu Bazaar",
    tooltip="Click for info"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62ae34e1f6157fb5caf8be2a0e8bc4ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62ae34e1f6157fb5caf8be2a0e8bc4ce = L.map(
#                 &quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot;,
#                 {
#                     center: [41.3111, 69.2797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var marker_76a42659215d87759a1a80d302208596 = L.marker(
#                 [41.3275, 69.2817],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#         var popup_aedbb7a8e3692d6e9968395eb89bd11f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be34b542420f1ffb720b54d7f9e2cb78 = $(`&lt;div id=&quot;html_be34b542420f1ffb720b54d7f9e2cb78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chorsu Bazaar&lt;/div&gt;`)[0];
#                 popup_aedbb7a8e3692d6e9968395eb89bd11f.setContent(html_be34b542420f1ffb720b54d7f9e2cb78);
#
#
#
#         marker_76a42659215d87759a1a80d302208596.bindPopup(popup_aedbb7a8e3692d6e9968395eb89bd11f)
#         ;
#
#
#
#
#             marker_76a42659215d87759a1a80d302208596.bindTooltip(
#                 `&lt;div&gt;
#                      Click for info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You can also use icons:

# %%
folium.Marker(
    [41.3, 69.25],
    popup="Example Point",
    icon=folium.Icon(color="green", icon="info-sign")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62ae34e1f6157fb5caf8be2a0e8bc4ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62ae34e1f6157fb5caf8be2a0e8bc4ce = L.map(
#                 &quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot;,
#                 {
#                     center: [41.3111, 69.2797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var marker_76a42659215d87759a1a80d302208596 = L.marker(
#                 [41.3275, 69.2817],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#         var popup_aedbb7a8e3692d6e9968395eb89bd11f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be34b542420f1ffb720b54d7f9e2cb78 = $(`&lt;div id=&quot;html_be34b542420f1ffb720b54d7f9e2cb78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chorsu Bazaar&lt;/div&gt;`)[0];
#                 popup_aedbb7a8e3692d6e9968395eb89bd11f.setContent(html_be34b542420f1ffb720b54d7f9e2cb78);
#
#
#
#         marker_76a42659215d87759a1a80d302208596.bindPopup(popup_aedbb7a8e3692d6e9968395eb89bd11f)
#         ;
#
#
#
#
#             marker_76a42659215d87759a1a80d302208596.bindTooltip(
#                 `&lt;div&gt;
#                      Click for info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var marker_6a2e3c1458a56bb3198678370585d1c1 = L.marker(
#                 [41.3, 69.25],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var icon_9b44d758a4e245f24bb809cafb731cb0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1b3ded7c44a41deece56c5ca1cee636d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eec2f8e600899fc551425ff1b7b25f07 = $(`&lt;div id=&quot;html_eec2f8e600899fc551425ff1b7b25f07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Example Point&lt;/div&gt;`)[0];
#                 popup_1b3ded7c44a41deece56c5ca1cee636d.setContent(html_eec2f8e600899fc551425ff1b7b25f07);
#
#
#
#         marker_6a2e3c1458a56bb3198678370585d1c1.bindPopup(popup_1b3ded7c44a41deece56c5ca1cee636d)
#         ;
#
#
#
#
#                 marker_6a2e3c1458a56bb3198678370585d1c1.setIcon(icon_9b44d758a4e245f24bb809cafb731cb0);
#
#
#             var marker_cd8b379ea426a48cec41805cc567ba8c = L.marker(
#                 [41.3, 69.25],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var icon_b865636345bf549eec757b093346c4b1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2a9cb9cb61f98dc44398be737ba2c697 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36c90917588cc7dcef4686b432abacb6 = $(`&lt;div id=&quot;html_36c90917588cc7dcef4686b432abacb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Example Point&lt;/div&gt;`)[0];
#                 popup_2a9cb9cb61f98dc44398be737ba2c697.setContent(html_36c90917588cc7dcef4686b432abacb6);
#
#
#
#         marker_cd8b379ea426a48cec41805cc567ba8c.bindPopup(popup_2a9cb9cb61f98dc44398be737ba2c697)
#         ;
#
#
#
#
#                 marker_cd8b379ea426a48cec41805cc567ba8c.setIcon(icon_b865636345bf549eec757b093346c4b1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:

# %% [markdown]
# # 🗾 3. Adding Shapes and Layers
# Circle Marker

# %%
folium.CircleMarker(
    location=[41.32, 69.29],
    radius=50,
    color="blue",
    fill=True,
    fill_opacity=0.4,
    popup="This is a circular area"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62ae34e1f6157fb5caf8be2a0e8bc4ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62ae34e1f6157fb5caf8be2a0e8bc4ce = L.map(
#                 &quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot;,
#                 {
#                     center: [41.3111, 69.2797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var marker_76a42659215d87759a1a80d302208596 = L.marker(
#                 [41.3275, 69.2817],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#         var popup_aedbb7a8e3692d6e9968395eb89bd11f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be34b542420f1ffb720b54d7f9e2cb78 = $(`&lt;div id=&quot;html_be34b542420f1ffb720b54d7f9e2cb78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chorsu Bazaar&lt;/div&gt;`)[0];
#                 popup_aedbb7a8e3692d6e9968395eb89bd11f.setContent(html_be34b542420f1ffb720b54d7f9e2cb78);
#
#
#
#         marker_76a42659215d87759a1a80d302208596.bindPopup(popup_aedbb7a8e3692d6e9968395eb89bd11f)
#         ;
#
#
#
#
#             marker_76a42659215d87759a1a80d302208596.bindTooltip(
#                 `&lt;div&gt;
#                      Click for info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var marker_6a2e3c1458a56bb3198678370585d1c1 = L.marker(
#                 [41.3, 69.25],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var icon_9b44d758a4e245f24bb809cafb731cb0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1b3ded7c44a41deece56c5ca1cee636d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eec2f8e600899fc551425ff1b7b25f07 = $(`&lt;div id=&quot;html_eec2f8e600899fc551425ff1b7b25f07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Example Point&lt;/div&gt;`)[0];
#                 popup_1b3ded7c44a41deece56c5ca1cee636d.setContent(html_eec2f8e600899fc551425ff1b7b25f07);
#
#
#
#         marker_6a2e3c1458a56bb3198678370585d1c1.bindPopup(popup_1b3ded7c44a41deece56c5ca1cee636d)
#         ;
#
#
#
#
#                 marker_6a2e3c1458a56bb3198678370585d1c1.setIcon(icon_9b44d758a4e245f24bb809cafb731cb0);
#
#
#             var marker_cd8b379ea426a48cec41805cc567ba8c = L.marker(
#                 [41.3, 69.25],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var icon_b865636345bf549eec757b093346c4b1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2a9cb9cb61f98dc44398be737ba2c697 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36c90917588cc7dcef4686b432abacb6 = $(`&lt;div id=&quot;html_36c90917588cc7dcef4686b432abacb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Example Point&lt;/div&gt;`)[0];
#                 popup_2a9cb9cb61f98dc44398be737ba2c697.setContent(html_36c90917588cc7dcef4686b432abacb6);
#
#
#
#         marker_cd8b379ea426a48cec41805cc567ba8c.bindPopup(popup_2a9cb9cb61f98dc44398be737ba2c697)
#         ;
#
#
#
#
#                 marker_cd8b379ea426a48cec41805cc567ba8c.setIcon(icon_b865636345bf549eec757b093346c4b1);
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157

# %% [markdown]
# Polygon Example

# %%
folium.Polygon(
    locations=[[41.3, 69.25], [41.35, 69.25], [41.35, 69.3]],
    color='purple',
    fill=True,
    popup="Custom polygon area"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62ae34e1f6157fb5caf8be2a0e8bc4ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62ae34e1f6157fb5caf8be2a0e8bc4ce = L.map(
#                 &quot;map_62ae34e1f6157fb5caf8be2a0e8bc4ce&quot;,
#                 {
#                     center: [41.3111, 69.2797],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var marker_76a42659215d87759a1a80d302208596 = L.marker(
#                 [41.3275, 69.2817],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#         var popup_aedbb7a8e3692d6e9968395eb89bd11f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be34b542420f1ffb720b54d7f9e2cb78 = $(`&lt;div id=&quot;html_be34b542420f1ffb720b54d7f9e2cb78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chorsu Bazaar&lt;/div&gt;`)[0];
#                 popup_aedbb7a8e3692d6e9968395eb89bd11f.setContent(html_be34b542420f1ffb720b54d7f9e2cb78);
#
#
#
#         marker_76a42659215d87759a1a80d302208596.bindPopup(popup_aedbb7a8e3692d6e9968395eb89bd11f)
#         ;
#
#
#
#
#             marker_76a42659215d87759a1a80d302208596.bindTooltip(
#                 `&lt;div&gt;
#                      Click for info
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var marker_6a2e3c1458a56bb3198678370585d1c1 = L.marker(
#                 [41.3, 69.25],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var icon_9b44d758a4e245f24bb809cafb731cb0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1b3ded7c44a41deece56c5ca1cee636d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eec2f8e600899fc551425ff1b7b25f07 = $(`&lt;div id=&quot;html_eec2f8e600899fc551425ff1b7b25f07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Example Point&lt;/div&gt;`)[0];
#                 popup_1b3ded7c44a41deece56c5ca1cee636d.setContent(html_eec2f8e600899fc551425ff1b7b25f07);
#
#
#
#         marker_6a2e3c1458a56bb3198678370585d1c1.bindPopup(popup_1b3ded7c44a41deece56c5ca1cee636d)
#         ;
#
#
#
#
#                 marker_6a2e3c1458a56bb3198678370585d1c1.setIcon(icon_9b44d758a4e245f24bb809cafb731cb0);
#
#
#             var marker_cd8b379ea426a48cec41805cc567ba8c = L.marker(
#                 [41.3, 69.25],
#                 {
# }
#             ).addTo(map_62ae34e1f6157fb5caf8be2a0e8bc4ce);
#
#
#             var icon_b865636345bf549eec757b093346c4b1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2a9cb9cb61f98dc44398be737ba2c697 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36c90917588cc7dcef4686b432abacb6 = $(`&lt;div id=&quot;html_36c90917588cc7dcef4686b432abacb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Example Point&lt;/div&gt;`)[0];
#                 popup_2a9cb9cb61f98dc44398be737ba2c697.setContent(html_36c90917588cc7dcef4686b432abacb6);
#
#
#
#         marker_cd8b379ea426a48cec41805cc567ba8c.bindPopup(popup_2a9cb9cb61f98dc44398be737ba2c697)
#         ;
#
#
#
#
#                 marker_cd8b379ea426a48cec41805cc567ba8c.setIcon(icon_b865636345bf549eec757b093346c4b1);
#
#
#             tile_layer_1c2effe40d5ac21ff3e6e420bc16bf7e.addTo(map_62ae34e1f6157

# %% [markdown]
# # 🧭 5. Adding Layers and LayerControl
#
# You can create multiple feature groups and toggle them:

# %%
fg1 = folium.FeatureGroup(name="Markets")
fg1.add_child(folium.Marker([41.31, 69.28], popup="Market A"))

fg2 = folium.FeatureGroup(name="Parks")
fg2.add_child(folium.CircleMarker([41.32, 69.30], radius=40, color='green', fill=True))

m = folium.Map(location=[41.31, 69.28], zoom_start=12)
fg1.add_to(m)
fg2.add_to(m)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c956ca55b4b1d3cba4ff687a32c37641 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c956ca55b4b1d3cba4ff687a32c37641&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c956ca55b4b1d3cba4ff687a32c37641 = L.map(
#                 &quot;map_c956ca55b4b1d3cba4ff687a32c37641&quot;,
#                 {
#                     center: [41.31, 69.28],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a53c4882d2335c8fb0c3e19d42f09c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a53c4882d2335c8fb0c3e19d42f09c8.addTo(map_c956ca55b4b1d3cba4ff687a32c37641);
#
#
#             var feature_group_669520f306cc5106760b54eaf853c14a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_39ede36e3bad95366378e787e336c8ab = L.marker(
#                 [41.31, 69.28],
#                 {
# }
#             ).addTo(feature_group_669520f306cc5106760b54eaf853c14a);
#
#
#         var popup_080f3d7fe98e6d7390e77548aeb5af15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45187ececaa996bf9985dff35cf3701e = $(`&lt;div id=&quot;html_45187ececaa996bf9985dff35cf3701e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Market A&lt;/div&gt;`)[0];
#                 popup_080f3d7fe98e6d7390e77548aeb5af15.setContent(html_45187ececaa996bf9985dff35cf3701e);
#
#
#
#         marker_39ede36e3bad95366378e787e336c8ab.bindPopup(popup_080f3d7fe98e6d7390e77548aeb5af15)
#         ;
#
#
#
#
#             feature_group_669520f306cc5106760b54eaf853c14a.addTo(map_c956ca55b4b1d3cba4ff687a32c37641);
#
#
#             var feature_group_4fea1a93fda19b7fed75cf2458769368 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_89800bbd7d734a09727b5167d350a0b2 = L.circleMarker(
#                 [41.32, 69.3],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_4fea1a93fda19b7fed75cf2458769368);
#
#
#             feature_group_4fea1a93fda19b7fed75cf2458769368.addTo(map_c956ca55b4b1d3cba4ff687a32c37641);
#
#
#             var layer_control_41c286bc8d8a965512598491298af786_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_5a53c4882d2335c8fb0c3e19d42f09c8,
#                 },
#                 overlays :  {
#                     &quot;Markets&quot; : feature_group_669520f306cc5106760b54eaf853c14a,
#                     &quot;Parks&quot; : feature_group_4fea1a93fda19b7fed75cf2458769368,
#                 },
#             };
#             let layer_control_41c286bc8d8a965512598491298af786 = L.control.layers(
#                 layer_control_41c286bc8d8a965512598491298af786_layers.base_layers,
#                 layer_control_41c286bc8d8a965512598491298af786_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_c956ca55b4b1d3cba4ff687a32c37641);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 📊 6. Integrating Data with Pandas
#
# Folium works beautifully with GeoPandas or Pandas datasets.
#
# Example with a CSV:

# %%
import pandas as pd
data = pd.read_csv('/content/locations.csv')

m = folium.Map(location=[41.3, 69.28], zoom_start=10)

for i, row in data.iterrows():
    folium.Marker(
        [row['lat'], row['lon']],
        popup=row['name']
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0e09ea3d013ccbfbc381afb6469e299 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0e09ea3d013ccbfbc381afb6469e299&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0e09ea3d013ccbfbc381afb6469e299 = L.map(
#                 &quot;map_d0e09ea3d013ccbfbc381afb6469e299&quot;,
#                 {
#                     center: [41.3, 69.28],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64e30909a683e9d7dc057dcf219a895e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64e30909a683e9d7dc057dcf219a895e.addTo(map_d0e09ea3d013ccbfbc381afb6469e299);
#
#
#             var marker_02d0c0a93c47975c818c2813fe9814ea = L.marker(
#                 [41.3275, 69.2817],
#                 {
# }
#             ).addTo(map_d0e09ea3d013ccbfbc381afb6469e299);
#
#
#         var popup_b07fb3657c7818a4e7300f277f21c562 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50c343cb63c6e031b643c76bd9de73df = $(`&lt;div id=&quot;html_50c343cb63c6e031b643c76bd9de73df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chorsu Bazaar&lt;/div&gt;`)[0];
#                 popup_b07fb3657c7818a4e7300f277f21c562.setContent(html_50c343cb63c6e031b643c76bd9de73df);
#
#
#
#         marker_02d0c0a93c47975c818c2813fe9814ea.bindPopup(popup_b07fb3657c7818a4e7300f277f21c562)
#         ;
#
#
#
#
#             var marker_195c37a85a6323dfb84bb90cec44e31b = L.marker(
#                 [41.3111, 69.2797],
#                 {
# }
#             ).addTo(map_d0e09ea3d013ccbfbc381afb6469e299);
#
#
#         var popup_567a4802eb24a92605e2a2b04cd0cfda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30404138b4b398f992c1fe3f641d70c0 = $(`&lt;div id=&quot;html_30404138b4b398f992c1fe3f641d70c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Amir Timur Square&lt;/div&gt;`)[0];
#                 popup_567a4802eb24a92605e2a2b04cd0cfda.setContent(html_30404138b4b398f992c1fe3f641d70c0);
#
#
#
#         marker_195c37a85a6323dfb84bb90cec44e31b.bindPopup(popup_567a4802eb24a92605e2a2b04cd0cfda)
#         ;
#
#
#
#
#             var marker_08080f7628970305814761464496e180 = L.marker(
#                 [41.3386, 69.3342],
#                 {
# }
#             ).addTo(map_d0e09ea3d013ccbfbc381afb6469e299);
#
#
#         var popup_f26328a12ace416efe3e459c048c9ad4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e40f15a7fad6e8a2bb34dba72aade1b8 = $(`&lt;div id=&quot;html_e40f15a7fad6e8a2bb34dba72aade1b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tashkent Tower&lt;/div&gt;`)[0];
#                 popup_f26328a12ace416efe3e459c048c9ad4.setContent(html_e40f15a7fad6e8a2bb34dba72aade1b8);
#
#
#
#         marker_08080f7628970305814761464496e180.bindPopup(popup_f26328a12ace416efe3e459c048c9ad4)
#         ;
#
#
#
#
#             var marker_c8b5274e0b1dc05c11dce3ada7434e79 = L.marker(
#                 [41.3365, 69.2745],
#                 {
# }
#             ).addTo(map_d0e09ea3d013ccbfbc381afb6469e299);
#
#
#         var popup_bb93be1088ef25dae3fe1ab5248ff258 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab84ce24eb0d27d9a89959d968687d32 = $(`&lt;div id=&quot;html_ab84ce24eb0d27d9a89959d968687d32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Minor Mosque&lt;/div&gt;`)[0];
#                 popup_bb93be1088ef25dae3fe1ab5248ff258.setContent(html_ab84ce24eb0d27d9a89959d968687d32);
#
#
#
#         marker_c8b5274e0b1dc05c11dce3ada7434e79.bindPopup(popup_bb93be1088ef25dae3fe1ab5248ff258)
#         ;
#
#
#
#
#             var marker_3a6b84c9569c210c7829787ae4b8a88d = L.marker(
#                 [41.3053, 69.2764],
#                 {
# }
#             ).addTo(map_d0e09ea3d013ccbfbc381afb6469e299);
#
#
#         var popup_d95b391642eb03af7bb4584b753be1f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adbfd25b93949e2e1057b5fd7a32e409 = $(`&lt;div id=&quot;html_adbfd25b93949e2e1057b5fd7a32e409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magic City Park&lt;/div&gt;`)[0];
#                 popup_d95b391642eb03af7bb4584b753be1f8.setContent(html_adbfd25b93949e2e1057b5fd7a32e409);
#
#
#
#         marker_3a6b84c9569c210c7829787a

# %% [markdown]
# # 🧠 7. Choropleth Maps (Thematic Maps)
#
# Choropleth maps display statistical data by region.

# %%
import json

# Load the geojson file
with open('uzbek_regions.geojson') as f:
    geo_data = json.load(f)

folium.Choropleth(
    geo_data=geo_data,
    name='choropleth',
    data=df,
    columns=['region', 'population'],
    key_on='feature.properties.name',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Population by Region'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35a7b7c0bf6b33c238bc5c3a4bc5bf76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35a7b7c0bf6b33c238bc5c3a4bc5bf76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35a7b7c0bf6b33c238bc5c3a4bc5bf76 = L.map(
#                 &quot;map_35a7b7c0bf6b33c238bc5c3a4bc5bf76&quot;,
#                 {
#                     center: [41.3, 69.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b751ebd6c50a8045d7d3d1713be7197 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b751ebd6c50a8045d7d3d1713be7197.addTo(map_35a7b7c0bf6b33c238bc5c3a4bc5bf76);
#
#
#             var choropleth_64a3303c21e4f6b65cc8f884a3d132fd = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Fergana&quot;: case &quot;Samarkand&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Namangan&quot;: case &quot;Surkhandarya&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Bukhara&quot;: case &quot;Khorezm&quot;: case &quot;Karakalpakstan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Navoi&quot;: case &quot;Jizzakh&quot;: case &quot;Sirdarya&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_21854cea95c07331989ffee79f23cca5 = L.geoJson(null, {
#                 onEachFeature: geo_json_21854cea95c07331989ffee79f23cca5_onEachFeature,
#
#                 style: geo_json_21854cea95c07331989ffee79f23cca5_styler,
#             ...{
# }
#         });
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_add (data) {
#             geo_json_21854cea95c07331989ffee79f23cca5
#                 .addData(data);
#         }
#             geo_json_21854cea95c07331989ffee79f23cca5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[69.0, 41.0], [69.8, 41.0], [69.8, 41.4], [69.0, 41.4], [69.0, 41.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Tashkent&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[72.0, 40.6], [72.4, 40.6], [72.4, 40.9], [72.0, 40.9], [72.0, 40.6]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Andijan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[71.4, 40.2], [72.1, 40.2], [72.1, 40.6], [71.4, 40.6], [71.4, 40.2]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Fergana&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[71.2, 40.8], [71.8, 40.8], [71.8, 41.2], [71.2, 41.2], [71.2, 40.8]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Namangan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[66.7, 39.4], [67.3, 39.4], [67.3, 39.9], [66.7, 39.9], [66.7, 39.4]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Samarkand&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[63.8, 39.8], [64.6, 39.8], [64.6, 40.4], [63.8, 40.4], [63.8, 39.8]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;prop

# %% [markdown]
# # 💾 8. Saving and Sharing Maps
#
# You can export interactive maps as HTML files.

# %%
m.save('tashkent_map.html')

# %% [markdown]
# # 🧰 9. Advanced Add-Ons
#
# MiniMap: Adds a small navigation map.

# %%
from folium.plugins import MiniMap
MiniMap().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35a7b7c0bf6b33c238bc5c3a4bc5bf76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35a7b7c0bf6b33c238bc5c3a4bc5bf76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35a7b7c0bf6b33c238bc5c3a4bc5bf76 = L.map(
#                 &quot;map_35a7b7c0bf6b33c238bc5c3a4bc5bf76&quot;,
#                 {
#                     center: [41.3, 69.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b751ebd6c50a8045d7d3d1713be7197 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b751ebd6c50a8045d7d3d1713be7197.addTo(map_35a7b7c0bf6b33c238bc5c3a4bc5bf76);
#
#
#             var choropleth_64a3303c21e4f6b65cc8f884a3d132fd = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Fergana&quot;: case &quot;Samarkand&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Namangan&quot;: case &quot;Surkhandarya&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Bukhara&quot;: case &quot;Khorezm&quot;: case &quot;Karakalpakstan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Navoi&quot;: case &quot;Jizzakh&quot;: case &quot;Sirdarya&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_21854cea95c07331989ffee79f23cca5 = L.geoJson(null, {
#                 onEachFeature: geo_json_21854cea95c07331989ffee79f23cca5_onEachFeature,
#
#                 style: geo_json_21854cea95c07331989ffee79f23cca5_styler,
#             ...{
# }
#         });
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_add (data) {
#             geo_json_21854cea95c07331989ffee79f23cca5
#                 .addData(data);
#         }
#             geo_json_21854cea95c07331989ffee79f23cca5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[69.0, 41.0], [69.8, 41.0], [69.8, 41.4], [69.0, 41.4], [69.0, 41.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Tashkent&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[72.0, 40.6], [72.4, 40.6], [72.4, 40.9], [72.0, 40.9], [72.0, 40.6]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Andijan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[71.4, 40.2], [72.1, 40.2], [72.1, 40.6], [71.4, 40.6], [71.4, 40.2]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Fergana&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[71.2, 40.8], [71.8, 40.8], [71.8, 41.2], [71.2, 41.2], [71.2, 40.8]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Namangan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[66.7, 39.4], [67.3, 39.4], [67.3, 39.9], [66.7, 39.9], [66.7, 39.4]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;p

# %% [markdown]
# HeatMap: Visualizes point density.

# %%
data = pd.read_csv('/content/locations.csv')

# %%
from folium.plugins import HeatMap
HeatMap(data[['lat', 'lon']]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35a7b7c0bf6b33c238bc5c3a4bc5bf76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35a7b7c0bf6b33c238bc5c3a4bc5bf76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35a7b7c0bf6b33c238bc5c3a4bc5bf76 = L.map(
#                 &quot;map_35a7b7c0bf6b33c238bc5c3a4bc5bf76&quot;,
#                 {
#                     center: [41.3, 69.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b751ebd6c50a8045d7d3d1713be7197 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b751ebd6c50a8045d7d3d1713be7197.addTo(map_35a7b7c0bf6b33c238bc5c3a4bc5bf76);
#
#
#             var choropleth_64a3303c21e4f6b65cc8f884a3d132fd = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Fergana&quot;: case &quot;Samarkand&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Namangan&quot;: case &quot;Surkhandarya&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Bukhara&quot;: case &quot;Khorezm&quot;: case &quot;Karakalpakstan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Navoi&quot;: case &quot;Jizzakh&quot;: case &quot;Sirdarya&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_21854cea95c07331989ffee79f23cca5 = L.geoJson(null, {
#                 onEachFeature: geo_json_21854cea95c07331989ffee79f23cca5_onEachFeature,
#
#                 style: geo_json_21854cea95c07331989ffee79f23cca5_styler,
#             ...{
# }
#         });
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_add (data) {
#             geo_json_21854cea95c07331989ffee79f23cca5
#                 .addData(data);
#         }
#             geo_json_21854cea95c07331989ffee79f23cca5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[69.0, 41.0], [69.8, 41.0], [69.8, 41.4], [69.0, 41.4], [69.0, 41.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Tashkent&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[72.0, 40.6], [72.4, 40.6], [72.4, 40.9], [72.0, 40.9], [72.0, 40.6]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Andijan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[71.4, 40.2], [72.1, 40.2], [72.1, 40.6], [71.4, 40.6], [71.4, 40.2]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Fergana&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[71.2, 40.8], [71.8, 40.8], [71.8, 41.2], [71.2, 41.2], [71.2, 40.8]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Namangan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;:

# %% [markdown]
# MarkerCluster: Groups nearby points.

# %%
from folium.plugins import MarkerCluster
MarkerCluster(data[['lat', 'lon']].values.tolist()).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35a7b7c0bf6b33c238bc5c3a4bc5bf76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35a7b7c0bf6b33c238bc5c3a4bc5bf76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35a7b7c0bf6b33c238bc5c3a4bc5bf76 = L.map(
#                 &quot;map_35a7b7c0bf6b33c238bc5c3a4bc5bf76&quot;,
#                 {
#                     center: [41.3, 69.3],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b751ebd6c50a8045d7d3d1713be7197 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b751ebd6c50a8045d7d3d1713be7197.addTo(map_35a7b7c0bf6b33c238bc5c3a4bc5bf76);
#
#
#             var choropleth_64a3303c21e4f6b65cc8f884a3d132fd = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_styler(feature) {
#             switch(feature.properties.name) {
#                 case &quot;Fergana&quot;: case &quot;Samarkand&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Namangan&quot;: case &quot;Surkhandarya&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Bukhara&quot;: case &quot;Khorezm&quot;: case &quot;Karakalpakstan&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;Navoi&quot;: case &quot;Jizzakh&quot;: case &quot;Sirdarya&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_21854cea95c07331989ffee79f23cca5 = L.geoJson(null, {
#                 onEachFeature: geo_json_21854cea95c07331989ffee79f23cca5_onEachFeature,
#
#                 style: geo_json_21854cea95c07331989ffee79f23cca5_styler,
#             ...{
# }
#         });
#
#         function geo_json_21854cea95c07331989ffee79f23cca5_add (data) {
#             geo_json_21854cea95c07331989ffee79f23cca5
#                 .addData(data);
#         }
#             geo_json_21854cea95c07331989ffee79f23cca5_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[69.0, 41.0], [69.8, 41.0], [69.8, 41.4], [69.0, 41.4], [69.0, 41.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Tashkent&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[72.0, 40.6], [72.4, 40.6], [72.4, 40.9], [72.0, 40.9], [72.0, 40.6]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Andijan&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[71.4, 40.2], [72.1, 40.2], [72.1, 40.6], [71.4, 40.6], [71.4, 4

# %% [markdown]
# # 🏁 Summary

# %% [markdown]
# | Task                | Folium Function                             |
# | ------------------- | ------------------------------------------- |
# | Create map          | `folium.Map()`                              |
# | Add marker          | `folium.Marker()`                           |
# | Draw circle/polygon | `folium.CircleMarker()`, `folium.Polygon()` |
# | Thematic map        | `folium.Choropleth()`                       |
# | Interactive layers  | `folium.LayerControl()`                     |
# | Plugins             | `folium.plugins.*`                          |
# | Save                | `map.save('map.html')`                      |
